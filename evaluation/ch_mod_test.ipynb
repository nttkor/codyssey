# %%
upper_list_seed = list(range(0,6))
upper_list = list(map(lambda x:chr(x+ord('a')),upper_list_seed))
#[chr(i +ord('a')) for i in upper_list_seed]
upper_list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
upper_list = [chr((i-ord('A')-3)%26+ord('A')) for i in range(ord('A'),ord('Z')+1)]
lower_list = [chr((i-ord('a')-3)%26+ord('a')) for i in range(ord('a'),ord('z')+1)]
for u,l in zip(upper_list, lower_list):
    print(u,l,end=',')
# Out:
# X x,Y y,Z z,A a,B b,C c,D d,E e,F f,G g,H h,I i,J j,K k,L l,M m,N n,O o,P p,Q q,R r,S s,T t,U u,V v,W w,

# %%
def decode(target_text, shift):
    decoded = ""
    base=''
    for ch in target_text:
        if ch.isalpha():
            base = ord('A') if ch.isupper() else ord('a')
            decoded += chr((ord(ch)-base-shift)%26+base)
        else:
            decoded += ch
    return decoded

# %%
target_text = "abcdefg"
for i in range(1,10):
    decoded_text = decode(target_text,i)
    print(decoded_text)
# Out:
# zabcdef
# yzabcde
# xyzabcd
# wxyzabc
# vwxyzab
# uvwxyza
# tuvwxyz
# stuvwxy
# rstuvwx

# %%
try:
    with open('evaluation/password.txt',mode = 'r',encoding = 'utf-8') as f:
        c_text = f.read()
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 with open('evaluation/password.txt',mode = 'r',encoding = 'utf-8') as f:
#       2     c_text = f.read()
#
# File /var/data/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'evaluation/password.txt'
